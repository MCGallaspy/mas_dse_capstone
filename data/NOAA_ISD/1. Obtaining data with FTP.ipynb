# %%
import ftplib
import gzip
import pandas as pd

# %%
def get_file(ftp, fname):
    result = bytes()
    def append_to_bytes(bs):
        nonlocal result
        result += bs
    ftp.retrbinary('RETR {}'.format(fname), append_to_bytes)
    return result

# %%
ftp = ftplib.FTP('ftp.ncdc.noaa.gov')
ftp.login()
# Out:
# '230-****** WARNING ** WARNING ** WARNING ** WARNING ** WARNING ******\n ** This is a United States Department of Commerce computer     **\n ** system, which may be accessed and used only for             **\n ** official Government business by authorized personnel.       **\n ** Unauthorized access or use of this computer system may      **\n ** subject violators to criminal, civil, and/or administrative **\n ** action.  All information on this computer system may be     **\n ** intercepted, recorded, read, copied, and disclosed by and   **\n ** to authorized personnel for official purposes, including    **\n ** criminal investigations.  Access or use of this computer    **\n ** system by any person, whether authorized or unauthorized,   **\n ** constitutes consent to these terms.                         **\n ****** WARNING ** WARNING ** WARNING ** WARNING ** WARNING ******\n230 Anonymous access granted, restrictions apply'

# %%
ftp.cwd('pub/data/noaa/2020/')
files = list(ftp.mlsd())

# %%
files
# Out:
# [('.',
#   {'modify': '20200131154047',
#    'perm': 'fle',
#    'type': 'cdir',
#    'unique': '3CU17328E50',
#    'unix.group': '4021',
#    'unix.mode': '0775',
#    'unix.owner': '4021'}),
#  ('..',
#   {'modify': '20200131154120',
#    'perm': 'fle',
#    'type': 'pdir',
#    'unique': '3CU2F87CC5',
#    'unix.group': '4021',
#    'unix.mode': '0775',
#    'unix.owner': '4021'}),
#  ('359270-99999-2020.gz',
#   {'modify': '20200131152513',
#    'perm': 'adfr',
#    'size': '8374',
#    'type': 'file',
#    'unique': '3CU17BF18D8',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('715820-99999-2020.gz',
#   {'modify': '20200131152939',
#    'perm': 'adfr',
#    'size': '131991',
#    'type': 'file',
#    'unique': '3CU17CF2A43',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('715901-99999-2020.gz',
#   {'modify': '20200131152939',
#    'perm': 'adfr',
#    'size': '9696',
#    'type': 'file',
#    'unique': '3CU17CF2A4C',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('356710-99999-2020.gz',
#   {'modify': '20200131152513',
#    'perm': 'adfr',
#    'size': '32762',
#    'type': 'file',
#    'unique': '3CU17BF18CA',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('042020-99999-2020.gz',
#   {'modify': '20200131152140',
#    'perm': 'adfr',
#    'size': '34698',
#    'type': 'file',
#    'unique': '3CU1736932C',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('713930-99999-2020.gz',
#   {'modify': '20200131152924',
#    'perm': 'adfr',
#    'size': '10746',
#    'type': 'file',
#    'unique': '3CU17CF2973',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('713980-99999-2020.gz',
#   {'modify': '20200131152924',
#    'perm': 'adfr',
#    'size': '11534',
#    'type': 'file',
#    'unique': '3CU17CF2977',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('353610-99999-2020.gz',
#   {'modify': '20200131152512',
#    'perm': 'adfr',
#    'size': '9728',
#    'type': 'file',
#    'unique': '3CU17BF18AF',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('353630-99999-2020.gz',
#   {'modify': '20200131152512',
#    'perm': 'adfr',
#    'size': '9967',
#    'type': 'file',
#    'unique': '3CU17BF18B2',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('712625-99999-2020.gz',
#   {'modify': '20200131152913',
#    'perm': 'adfr',
#    'size': '22952',
#    'type': 'file',
#    'unique': '3CU17CF28E3',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('713640-99999-2020.gz',
#   {'modify': '20200131152922',
#    'perm': 'adfr',
#    'size': '31269',
#    'type': 'file',
#    'unique': '3CU17CF2956',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('713650-99999-2020.gz',
#   {'modify': '20200131152923',
#    'perm': 'adfr',
#    'size': '30030',
#    'type': 'file',
#    'unique': '3CU17CF2957',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('713890-99999-2020.gz',
#   {'modify': '20200131152924',
#    'perm': 'adfr',
#    'size': '21869',
#    'type': 'file',
#    'unique': '3CU17CF2970',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('350670-99999-2020.gz',
#   {'modify': '20200131152510',
#    'perm': 'adfr',
#    'size': '10611',
#    'type': 'file',
#    'unique': '3CU17BF188F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('712210-99999-2020.gz',
#   {'modify': '20200131152910',
#    'perm': 'adfr',
#    'size': '21159',
#    'type': 'file',
#    'unique': '3CU17CF28B6',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('711900-99999-2020.gz',
#   {'modify': '20200131152907',
#    'perm': 'adfr',
#    'size': '23609',
#    'type': 'file',
#    'unique': '3CU17CF2896',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('711960-99999-2020.gz',
#   {'modify': '20200131152908',
#    'perm': 'adfr',
#    'size': '35442',
#    'type': 'file',
#    'unique': '3CU17CF2899',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('349490-99999-2020.gz',
#   {'modify': '20200131152510',
#    'perm': 'adfr',
#    'size': '49746',
#    'type': 'file',
#    'unique': '3CU17BF1882',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('711650-99999-2020.gz',
#   {'modify': '20200131152906',
#    'perm': 'adfr',
#    'size': '28671',
#    'type': 'file',
#    'unique': '3CU17CF2884',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('041310-99999-2020.gz',
#   {'modify': '20200131152139',
#    'perm': 'adfr',
#    'size': '8772',
#    'type': 'file',
#    'unique': '3CU17369313',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('113160-99999-2020.gz',
#   {'modify': '20200131152248',
#    'perm': 'adfr',
#    'size': '23023',
#    'type': 'file',
#    'unique': '3CU17B30EBD',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('041240-99999-2020.gz',
#   {'modify': '20200131152139',
#    'perm': 'adfr',
#    'size': '9203',
#    'type': 'file',
#    'unique': '3CU17369310',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('346910-99999-2020.gz',
#   {'modify': '20200131152509',
#    'perm': 'adfr',
#    'size': '9705',
#    'type': 'file',
#    'unique': '3CU17BF186B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('710660-99999-2020.gz',
#   {'modify': '20200131152857',
#    'perm': 'adfr',
#    'size': '64590',
#    'type': 'file',
#    'unique': '3CU17CF281E',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('710840-99999-2020.gz',
#   {'modify': '20200131152859',
#    'perm': 'adfr',
#    'size': '19289',
#    'type': 'file',
#    'unique': '3CU17CF2835',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('711020-99999-2020.gz',
#   {'modify': '20200131152901',
#    'perm': 'adfr',
#    'size': '13673',
#    'type': 'file',
#    'unique': '3CU17CF2845',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('343000-99999-2020.gz',
#   {'modify': '20200131152507',
#    'perm': 'adfr',
#    'size': '54883',
#    'type': 'file',
#    'unique': '3CU17BF184A',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('710210-99999-2020.gz',
#   {'modify': '20200131152853',
#    'perm': 'adfr',
#    'size': '25940',
#    'type': 'file',
#    'unique': '3CU17CB27DA',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('710140-99999-2020.gz',
#   {'modify': '20200131152853',
#    'perm': 'adfr',
#    'size': '6402',
#    'type': 'file',
#    'unique': '3CU17CB27D2',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('341990-99999-2020.gz',
#   {'modify': '20200131152507',
#    'perm': 'adfr',
#    'size': '11500',
#    'type': 'file',
#    'unique': '3CU17BF183C',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('342020-99999-2020.gz',
#   {'modify': '20200131152507',
#    'perm': 'adfr',
#    'size': '11315',
#    'type': 'file',
#    'unique': '3CU17BF183D',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('040820-99999-2020.gz',
#   {'modify': '20200131152139',
#    'perm': 'adfr',
#    'size': '7483',
#    'type': 'file',
#    'unique': '3CU17369307',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('703985-25377-2020.gz',
#   {'modify': '20200131152851',
#    'perm': 'adfr',
#    'size': '48367',
#    'type': 'file',
#    'unique': '3CU17CB27BD',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('040710-99999-2020.gz',
#   {'modify': '20200131152139',
#    'perm': 'adfr',
#    'size': '6010',
#    'type': 'file',
#    'unique': '3CU17369301',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('703606-25629-2020.gz',
#   {'modify': '20200131152849',
#    'perm': 'adfr',
#    'size': '35795',
#    'type': 'file',
#    'unique': '3CU17CB27A1',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('703610-25339-2020.gz',
#   {'modify': '20200131152849',
#    'perm': 'adfr',
#    'size': '97138',
#    'type': 'file',
#    'unique': '3CU17CB27A2',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('339020-99999-2020.gz',
#   {'modify': '20200131152505',
#    'perm': 'adfr',
#    'size': '40484',
#    'type': 'file',
#    'unique': '3CU17BF181F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('110750-99999-2020.gz',
#   {'modify': '20200131152244',
#    'perm': 'adfr',
#    'size': '13987',
#    'type': 'file',
#    'unique': '3CU17B30E58',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('702606-96401-2020.gz',
#   {'modify': '20200131152843',
#    'perm': 'adfr',
#    'size': '6985',
#    'type': 'file',
#    'unique': '3CU17CB2762',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('688490-99999-2020.gz',
#   {'modify': '20200131152836',
#    'perm': 'adfr',
#    'size': '9557',
#    'type': 'file',
#    'unique': '3CU17CB2702',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('689200-99999-2020.gz',
#   {'modify': '20200131152836',
#    'perm': 'adfr',
#    'size': '9400',
#    'type': 'file',
#    'unique': '3CU17CB270B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('702190-26615-2020.gz',
#   {'modify': '20200131152842',
#    'perm': 'adfr',
#    'size': '58067',
#    'type': 'file',
#    'unique': '3CU17CB2750',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('702350-26534-2020.gz',
#   {'modify': '20200131152843',
#    'perm': 'adfr',
#    'size': '59269',
#    'type': 'file',
#    'unique': '3CU17CB275A',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('040131-99999-2020.gz',
#   {'modify': '20200131152138',
#    'perm': 'adfr',
#    'size': '10431',
#    'type': 'file',
#    'unique': '3CU173692EC',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('110210-99999-2020.gz',
#   {'modify': '20200131152241',
#    'perm': 'adfr',
#    'size': '14548',
#    'type': 'file',
#    'unique': '3CU17B30E3F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('011510-99999-2020.gz',
#   {'modify': '20200131152038',
#    'perm': 'adfr',
#    'size': '52015',
#    'type': 'file',
#    'unique': '3CU17328EBB',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('688400-99999-2020.gz',
#   {'modify': '20200131152836',
#    'perm': 'adfr',
#    'size': '9446',
#    'type': 'file',
#    'unique': '3CU17CB26FE',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('110200-99999-2020.gz',
#   {'modify': '20200131152241',
#    'perm': 'adfr',
#    'size': '13380',
#    'type': 'file',
#    'unique': '3CU17B30E3E',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('110100-99999-2020.gz',
#   {'modify': '20200131152241',
#    'perm': 'adfr',
#    'size': '80000',
#    'type': 'file',
#    'unique': '3CU17B30E33',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('322520-99999-2020.gz',
#   {'modify': '20200131152501',
#    'perm': 'adfr',
#    'size': '6215',
#    'type': 'file',
#    'unique': '3CU17BB17CE',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('999999-94644-2020.gz',
#   {'modify': '20200131154035',
#    'perm': 'adfr',
#    'size': '186854',
#    'type': 'file',
#    'unique': '3CU25E95836',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('999999-96408-2020.gz',
#   {'modify': '20200131154041',
#    'perm': 'adfr',
#    'size': '197119',
#    'type': 'file',
#    'unique': '3CU25E95843',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('A00023-63890-2020.gz',
#   {'modify': '20200131154044',
#    'perm': 'adfr',
#    'size': '31140',
#    'type': 'file',
#    'unique': '3CU25E95857',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('319690-99999-2020.gz',
#   {'modify': '20200131152500',
#    'perm': 'adfr',
#    'size': '10080',
#    'type': 'file',
#    'unique': '3CU17BB17B8',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('999999-64758-2020.gz',
#   {'modify': '20200131154022',
#    'perm': 'adfr',
#    'size': '187103',
#    'type': 'file',
#    'unique': '3CU25E95809',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('999999-93243-2020.gz',
#   {'modify': '20200131154026',
#    'perm': 'adfr',
#    'size': '197892',
#    'type': 'file',
#    'unique': '3CU25E95817',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('999999-93816-2020.gz',
#   {'modify': '20200131154027',
#    'perm': 'adfr',
#    'size': '77389',
#    'type': 'file',
#    'unique': '3CU25E9581C',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('684240-99999-2020.gz',
#   {'modify': '20200131152829',
#    'perm': 'adfr',
#    'size': '31517',
#    'type': 'file',
#    'unique': '3CU17CB2692',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('684610-99999-2020.gz',
#   {'modify': '20200131152830',
#    'perm': 'adfr',
#    'size': '15789',
#    'type': 'file',
#    'unique': '3CU17CB269D',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('998306-99999-2020.gz',
#   {'modify': '20200131153825',
#    'perm': 'adfr',
#    'size': '7199',
#    'type': 'file',
#    'unique': '3CU25E556BE',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('998431-99999-2020.gz',
#   {'modify': '20200131153826',
#    'perm': 'adfr',
#    'size': '20524',
#    'type': 'file',
#    'unique': '3CU25E556D4',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('999999-00325-2020.gz',
#   {'modify': '20200131153830',
#    'perm': 'adfr',
#    'size': '80654',
#    'type': 'file',
#    'unique': '3CU25E55719',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('999999-03047-2020.gz',
#   {'modify': '20200131153834',
#    'perm': 'adfr',
#    'size': '211860',
#    'type': 'file',
#    'unique': '3CU25E5573B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('103480-99999-2020.gz',
#   {'modify': '20200131152236',
#    'perm': 'adfr',
#    'size': '23151',
#    'type': 'file',
#    'unique': '3CU17B30DEF',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('683290-99999-2020.gz',
#   {'modify': '20200131152827',
#    'perm': 'adfr',
#    'size': '10848',
#    'type': 'file',
#    'unique': '3CU17CB2668',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('104360-99999-2020.gz',
#   {'modify': '20200131152237',
#    'perm': 'adfr',
#    'size': '24298',
#    'type': 'file',
#    'unique': '3CU17B30DF7',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('682690-99999-2020.gz',
#   {'modify': '20200131152826',
#    'perm': 'adfr',
#    'size': '9266',
#    'type': 'file',
#    'unique': '3CU17CB2650',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('683280-99999-2020.gz',
#   {'modify': '20200131152827',
#    'perm': 'adfr',
#    'size': '3079',
#    'type': 'file',
#    'unique': '3CU17CB2667',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('309490-99999-2020.gz',
#   {'modify': '20200131152456',
#    'perm': 'adfr',
#    'size': '9799',
#    'type': 'file',
#    'unique': '3CU17BB175C',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('998179-99999-2020.gz',
#   {'modify': '20200131153820',
#    'perm': 'adfr',
#    'size': '19487',
#    'type': 'file',
#    'unique': '3CU25E55632',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('998205-99999-2020.gz',
#   {'modify': '20200131153821',
#    'perm': 'adfr',
#    'size': '12659',
#    'type': 'file',
#    'unique': '3CU25E5564C',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('998299-99999-2020.gz',
#   {'modify': '20200131153825',
#    'perm': 'adfr',
#    'size': '10664',
#    'type': 'file',
#    'unique': '3CU25E556B8',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('308290-99999-2020.gz',
#   {'modify': '20200131152455',
#    'perm': 'adfr',
#    'size': '9529',
#    'type': 'file',
#    'unique': '3CU17BB1751',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('998176-99999-2020.gz',
#   {'modify': '20200131153820',
#    'perm': 'adfr',
#    'size': '12332',
#    'type': 'file',
#    'unique': '3CU25E5562E',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('681880-99999-2020.gz',
#   {'modify': '20200131152825',
#    'perm': 'adfr',
#    'size': '8863',
#    'type': 'file',
#    'unique': '3CU17CB2634',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('998009-99999-2020.gz',
#   {'modify': '20200131153818',
#    'perm': 'adfr',
#    'size': '12179',
#    'type': 'file',
#    'unique': '3CU25E55618',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('103340-99999-2020.gz',
#   {'modify': '20200131152235',
#    'perm': 'adfr',
#    'size': '27929',
#    'type': 'file',
#    'unique': '3CU17B30DE9',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('678550-99999-2020.gz',
#   {'modify': '20200131152822',
#    'perm': 'adfr',
#    'size': '2016',
#    'type': 'file',
#    'unique': '3CU17CB25EF',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('997361-99999-2020.gz',
#   {'modify': '20200131153812',
#    'perm': 'adfr',
#    'size': '20835',
#    'type': 'file',
#    'unique': '3CU25E55596',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('677910-99999-2020.gz',
#   {'modify': '20200131152822',
#    'perm': 'adfr',
#    'size': '2240',
#    'type': 'file',
#    'unique': '3CU17CB25EA',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('997307-99999-2020.gz',
#   {'modify': '20200131153809',
#    'perm': 'adfr',
#    'size': '14175',
#    'type': 'file',
#    'unique': '3CU25E55564',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('672871-99999-2020.gz',
#   {'modify': '20200131152818',
#    'perm': 'adfr',
#    'size': '1644',
#    'type': 'file',
#    'unique': '3CU17CB2593',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('997287-99999-2020.gz',
#   {'modify': '20200131153808',
#    'perm': 'adfr',
#    'size': '21417',
#    'type': 'file',
#    'unique': '3CU25E55552',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('677730-99999-2020.gz',
#   {'modify': '20200131152822',
#    'perm': 'adfr',
#    'size': '2078',
#    'type': 'file',
#    'unique': '3CU17CB25E3',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('089270-99999-2020.gz',
#   {'modify': '20200131152234',
#    'perm': 'adfr',
#    'size': '1466',
#    'type': 'file',
#    'unique': '3CU17B30DCA',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('997176-99999-2020.gz',
#   {'modify': '20200131153806',
#    'perm': 'adfr',
#    'size': '18263',
#    'type': 'file',
#    'unique': '3CU25E55523',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('997280-99999-2020.gz',
#   {'modify': '20200131153808',
#    'perm': 'adfr',
#    'size': '21112',
#    'type': 'file',
#    'unique': '3CU25E55546',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('997281-99999-2020.gz',
#   {'modify': '20200131153808',
#    'perm': 'adfr',
#    'size': '21344',
#    'type': 'file',
#    'unique': '3CU25E55549',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('300890-99999-2020.gz',
#   {'modify': '20200131152453',
#    'perm': 'adfr',
#    'size': '9689',
#    'type': 'file',
#    'unique': '3CU17BB1716',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('997172-99999-2020.gz',
#   {'modify': '20200131153806',
#    'perm': 'adfr',
#    'size': '7637',
#    'type': 'file',
#    'unique': '3CU25E5551F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('655280-99999-2020.gz',
#   {'modify': '20200131152814',
#    'perm': 'adfr',
#    'size': '6098',
#    'type': 'file',
#    'unique': '3CU17CB2540',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('655570-99999-2020.gz',
#   {'modify': '20200131152814',
#    'perm': 'adfr',
#    'size': '9067',
#    'type': 'file',
#    'unique': '3CU17CB2547',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('037430-99999-2020.gz',
#   {'modify': '20200131152134',
#    'perm': 'adfr',
#    'size': '24001',
#    'type': 'file',
#    'unique': '3CU1736929B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('994250-99999-2020.gz',
#   {'modify': '20200131153802',
#    'perm': 'adfr',
#    'size': '41191',
#    'type': 'file',
#    'unique': '3CU25E554EB',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('298020-99999-2020.gz',
#   {'modify': '20200131152452',
#    'perm': 'adfr',
#    'size': '10003',
#    'type': 'file',
#    'unique': '3CU17BB16F7',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('036913-99999-2020.gz',
#   {'modify': '20200131152133',
#    'perm': 'adfr',
#    'size': '30483',
#    'type': 'file',
#    'unique': '3CU1736928C',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('994084-99999-2020.gz',
#   {'modify': '20200131153801',
#    'perm': 'adfr',
#    'size': '35994',
#    'type': 'file',
#    'unique': '3CU25E554D7',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('297120-99999-2020.gz',
#   {'modify': '20200131152451',
#    'perm': 'adfr',
#    'size': '11953',
#    'type': 'file',
#    'unique': '3CU17BB16EA',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('654390-99999-2020.gz',
#   {'modify': '20200131152812',
#    'perm': 'adfr',
#    'size': '6571',
#    'type': 'file',
#    'unique': '3CU17CB2523',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('036733-99999-2020.gz',
#   {'modify': '20200131152133',
#    'perm': 'adfr',
#    'size': '38558',
#    'type': 'file',
#    'unique': '3CU17369287',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('994050-99999-2020.gz',
#   {'modify': '20200131153800',
#    'perm': 'adfr',
#    'size': '17511',
#    'type': 'file',
#    'unique': '3CU25E554CB',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('653870-99999-2020.gz',
#   {'modify': '20200131152811',
#    'perm': 'adfr',
#    'size': '23525',
#    'type': 'file',
#    'unique': '3CU17CB2518',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('294640-99999-2020.gz',
#   {'modify': '20200131152448',
#    'perm': 'adfr',
#    'size': '11762',
#    'type': 'file',
#    'unique': '3CU17BB16BE',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('994010-99999-2020.gz',
#   {'modify': '20200131153758',
#    'perm': 'adfr',
#    'size': '7282',
#    'type': 'file',
#    'unique': '3CU25E55498',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('994031-99999-2020.gz',
#   {'modify': '20200131153759',
#    'perm': 'adfr',
#    'size': '20292',
#    'type': 'file',
#    'unique': '3CU25E554B2',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('994032-99999-2020.gz',
#   {'modify': '20200131153800',
#    'perm': 'adfr',
#    'size': '17152',
#    'type': 'file',
#    'unique': '3CU25E554B4',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('295780-99999-2020.gz',
#   {'modify': '20200131152449',
#    'perm': 'adfr',
#    'size': '12212',
#    'type': 'file',
#    'unique': '3CU17BB16D3',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('967370-99999-2020.gz',
#   {'modify': '20200131153749',
#    'perm': 'adfr',
#    'size': '12501',
#    'type': 'file',
#    'unique': '3CU25E153D9',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('979800-99999-2020.gz',
#   {'modify': '20200131153755',
#    'perm': 'adfr',
#    'size': '12266',
#    'type': 'file',
#    'unique': '3CU25E55443',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('013170-99999-2020.gz',
#   {'modify': '20200131152044',
#    'perm': 'adfr',
#    'size': '28533',
#    'type': 'file',
#    'unique': '3CU17328F15',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('961710-99999-2020.gz',
#   {'modify': '20200131153745',
#    'perm': 'adfr',
#    'size': '10661',
#    'type': 'file',
#    'unique': '3CU25E1539E',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('013200-99999-2020.gz',
#   {'modify': '20200131152044',
#    'perm': 'adfr',
#    'size': '58214',
#    'type': 'file',
#    'unique': '3CU17328F17',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('959950-99999-2020.gz',
#   {'modify': '20200131153744',
#    'perm': 'adfr',
#    'size': '1404',
#    'type': 'file',
#    'unique': '3CU25E15386',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('288841-99999-2020.gz',
#   {'modify': '20200131152447',
#    'perm': 'adfr',
#    'size': '10082',
#    'type': 'file',
#    'unique': '3CU17BB1691',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('959400-99999-2020.gz',
#   {'modify': '20200131153743',
#    'perm': 'adfr',
#    'size': '14776',
#    'type': 'file',
#    'unique': '3CU25E15365',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('629410-99999-2020.gz',
#   {'modify': '20200131152757',
#    'perm': 'adfr',
#    'size': '259',
#    'type': 'file',
#    'unique': '3CU17CB2428',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('632270-99999-2020.gz',
#   {'modify': '20200131152757',
#    'perm': 'adfr',
#    'size': '1739',
#    'type': 'file',
#    'unique': '3CU17CB242D',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('633320-99999-2020.gz',
#   {'modify': '20200131152758',
#    'perm': 'adfr',
#    'size': '4690',
#    'type': 'file',
#    'unique': '3CU17CB2431',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('634020-99999-2020.gz',
#   {'modify': '20200131152758',
#    'perm': 'adfr',
#    'size': '5112',
#    'type': 'file',
#    'unique': '3CU17CB2436',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('958450-99999-2020.gz',
#   {'modify': '20200131153740',
#    'perm': 'adfr',
#    'size': '6606',
#    'type': 'file',
#    'unique': '3CU25E15344',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('958900-99999-2020.gz',
#   {'modify': '20200131153741',
#    'perm': 'adfr',
#    'size': '8391',
#    'type': 'file',
#    'unique': '3CU25E1534B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('643830-99999-2020.gz',
#   {'modify': '20200131152805',
#    'perm': 'adfr',
#    'size': '8525',
#    'type': 'file',
#    'unique': '3CU17CB24A7',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('958400-99999-2020.gz',
#   {'modify': '20200131153740',
#    'perm': 'adfr',
#    'size': '15445',
#    'type': 'file',
#    'unique': '3CU25E15342',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('645560-99999-2020.gz',
#   {'modify': '20200131152806',
#    'perm': 'adfr',
#    'size': '8055',
#    'type': 'file',
#    'unique': '3CU17CB24C5',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('646000-99999-2020.gz',
#   {'modify': '20200131152807',
#    'perm': 'adfr',
#    'size': '8026',
#    'type': 'file',
#    'unique': '3CU17CB24C8',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('646010-99999-2020.gz',
#   {'modify': '20200131152807',
#    'perm': 'adfr',
#    'size': '5388',
#    'type': 'file',
#    'unique': '3CU17CB24C9',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('013470-99999-2020.gz',
#   {'modify': '20200131152045',
#    'perm': 'adfr',
#    'size': '50927',
#    'type': 'file',
#    'unique': '3CU17328F2F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('958160-99999-2020.gz',
#   {'modify': '20200131153740',
#    'perm': 'adfr',
#    'size': '11472',
#    'type': 'file',
#    'unique': '3CU25E15327',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('085120-99999-2020.gz',
#   {'modify': '20200131152230',
#    'perm': 'adfr',
#    'size': '43057',
#    'type': 'file',
#    'unique': '3CU17B30D7B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('277990-99999-2020.gz',
#   {'modify': '20200131152442',
#    'perm': 'adfr',
#    'size': '11258',
#    'type': 'file',
#    'unique': '3CU17BB159C',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('624639-99999-2020.gz',
#   {'modify': '20200131152757',
#    'perm': 'adfr',
#    'size': '11732',
#    'type': 'file',
#    'unique': '3CU17CB241E',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('013580-99999-2020.gz',
#   {'modify': '20200131152045',
#    'perm': 'adfr',
#    'size': '19062',
#    'type': 'file',
#    'unique': '3CU17328F36',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('956340-99999-2020.gz',
#   {'modify': '20200131153735',
#    'perm': 'adfr',
#    'size': '16093',
#    'type': 'file',
#    'unique': '3CU25E152AE',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('956620-99999-2020.gz',
#   {'modify': '20200131153736',
#    'perm': 'adfr',
#    'size': '11016',
#    'type': 'file',
#    'unique': '3CU25E152C5',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('624200-99999-2020.gz',
#   {'modify': '20200131152756',
#    'perm': 'adfr',
#    'size': '6616',
#    'type': 'file',
#    'unique': '3CU17CB2410',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('956230-99999-2020.gz',
#   {'modify': '20200131153734',
#    'perm': 'adfr',
#    'size': '581',
#    'type': 'file',
#    'unique': '3CU25E152A5',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('084515-99999-2020.gz',
#   {'modify': '20200131152228',
#    'perm': 'adfr',
#    'size': '35209',
#    'type': 'file',
#    'unique': '3CU17B30D66',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('607750-99999-2020.gz',
#   {'modify': '20200131152748',
#    'perm': 'adfr',
#    'size': '29469',
#    'type': 'file',
#    'unique': '3CU17C72387',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('273330-99999-2020.gz',
#   {'modify': '20200131152439',
#    'perm': 'adfr',
#    'size': '12125',
#    'type': 'file',
#    'unique': '3CU17BB1566',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('955750-99999-2020.gz',
#   {'modify': '20200131153733',
#    'perm': 'adfr',
#    'size': '8194',
#    'type': 'file',
#    'unique': '3CU25E15284',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('604670-99999-2020.gz',
#   {'modify': '20200131152743',
#    'perm': 'adfr',
#    'size': '1539',
#    'type': 'file',
#    'unique': '3CU17C72324',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('605200-99999-2020.gz',
#   {'modify': '20200131152743',
#    'perm': 'adfr',
#    'size': '3800',
#    'type': 'file',
#    'unique': '3CU17C72332',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('953040-99999-2020.gz',
#   {'modify': '20200131153731',
#    'perm': 'adfr',
#    'size': '10324',
#    'type': 'file',
#    'unique': '3CU25E15258',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('606910-99999-2020.gz',
#   {'modify': '20200131152746',
#    'perm': 'adfr',
#    'size': '7634',
#    'type': 'file',
#    'unique': '3CU17C72365',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('607480-99999-2020.gz',
#   {'modify': '20200131152748',
#    'perm': 'adfr',
#    'size': '11575',
#    'type': 'file',
#    'unique': '3CU17C7237E',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('607650-99999-2020.gz',
#   {'modify': '20200131152748',
#    'perm': 'adfr',
#    'size': '28491',
#    'type': 'file',
#    'unique': '3CU17C72382',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('084330-99999-2020.gz',
#   {'modify': '20200131152228',
#    'perm': 'adfr',
#    'size': '63905',
#    'type': 'file',
#    'unique': '3CU17B30D62',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('603740-99999-2020.gz',
#   {'modify': '20200131152741',
#    'perm': 'adfr',
#    'size': '1709',
#    'type': 'file',
#    'unique': '3CU17C72302',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('949670-99999-2020.gz',
#   {'modify': '20200131153730',
#    'perm': 'adfr',
#    'size': '1194',
#    'type': 'file',
#    'unique': '3CU25E1521F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('268940-99999-2020.gz',
#   {'modify': '20200131152438',
#    'perm': 'adfr',
#    'size': '13139',
#    'type': 'file',
#    'unique': '3CU17BB153F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('268980-99999-2020.gz',
#   {'modify': '20200131152438',
#    'perm': 'adfr',
#    'size': '34418',
#    'type': 'file',
#    'unique': '3CU17BB1540',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('603720-99999-2020.gz',
#   {'modify': '20200131152741',
#    'perm': 'adfr',
#    'size': '1543',
#    'type': 'file',
#    'unique': '3CU17C72300',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('083480-99999-2020.gz',
#   {'modify': '20200131152226',
#    'perm': 'adfr',
#    'size': '40058',
#    'type': 'file',
#    'unique': '3CU17B30D50',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('033300-99999-2020.gz',
#   {'modify': '20200131152129',
#    'perm': 'adfr',
#    'size': '37730',
#    'type': 'file',
#    'unique': '3CU17369236',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('083030-99999-2020.gz',
#   {'modify': '20200131152225',
#    'perm': 'adfr',
#    'size': '12682',
#    'type': 'file',
#    'unique': '3CU17B30D49',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('948590-99999-2020.gz',
#   {'modify': '20200131153725',
#    'perm': 'adfr',
#    'size': '9605',
#    'type': 'file',
#    'unique': '3CU25E151AB',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('603400-99999-2020.gz',
#   {'modify': '20200131152740',
#    'perm': 'adfr',
#    'size': '31906',
#    'type': 'file',
#    'unique': '3CU17C722FA',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('947140-99999-2020.gz',
#   {'modify': '20200131153720',
#    'perm': 'adfr',
#    'size': '700',
#    'type': 'file',
#    'unique': '3CU25E1511B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('947610-99999-2020.gz',
#   {'modify': '20200131153722',
#    'perm': 'adfr',
#    'size': '662',
#    'type': 'file',
#    'unique': '3CU25E15147',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('947730-99999-2020.gz',
#   {'modify': '20200131153722',
#    'perm': 'adfr',
#    'size': '889',
#    'type': 'file',
#    'unique': '3CU25E15153',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('265090-99999-2020.gz',
#   {'modify': '20200131152436',
#    'perm': 'adfr',
#    'size': '13116',
#    'type': 'file',
#    'unique': '3CU17BB150E',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('946820-99999-2020.gz',
#   {'modify': '20200131153719',
#    'perm': 'adfr',
#    'size': '19795',
#    'type': 'file',
#    'unique': '3CU25E15107',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('033020-99999-2020.gz',
#   {'modify': '20200131152129',
#    'perm': 'adfr',
#    'size': '62107',
#    'type': 'file',
#    'unique': '3CU1736922E',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('587540-99999-2020.gz',
#   {'modify': '20200131152731',
#    'perm': 'adfr',
#    'size': '12194',
#    'type': 'file',
#    'unique': '3CU17C72280',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('596440-99999-2020.gz',
#   {'modify': '20200131152734',
#    'perm': 'adfr',
#    'size': '12002',
#    'type': 'file',
#    'unique': '3CU17C722B4',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('946800-99999-2020.gz',
#   {'modify': '20200131153719',
#    'perm': 'adfr',
#    'size': '2314',
#    'type': 'file',
#    'unique': '3CU25E15104',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('263130-99999-2020.gz',
#   {'modify': '20200131152434',
#    'perm': 'adfr',
#    'size': '10999',
#    'type': 'file',
#    'unique': '3CU17BB14EA',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('263590-99999-2020.gz',
#   {'modify': '20200131152434',
#    'perm': 'adfr',
#    'size': '11098',
#    'type': 'file',
#    'unique': '3CU17BB14F3',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('945953-99999-2020.gz',
#   {'modify': '20200131153713',
#    'perm': 'adfr',
#    'size': '36885',
#    'type': 'file',
#    'unique': '3CU25E150A1',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('946730-99999-2020.gz',
#   {'modify': '20200131153719',
#    'perm': 'adfr',
#    'size': '2040',
#    'type': 'file',
#    'unique': '3CU25E150F2',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('080750-99999-2020.gz',
#   {'modify': '20200131152222',
#    'perm': 'adfr',
#    'size': '76268',
#    'type': 'file',
#    'unique': '3CU17B30D00',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('262680-99999-2020.gz',
#   {'modify': '20200131152434',
#    'perm': 'adfr',
#    'size': '3394',
#    'type': 'file',
#    'unique': '3CU17BB14E5',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('583140-99999-2020.gz',
#   {'modify': '20200131152728',
#    'perm': 'adfr',
#    'size': '12899',
#    'type': 'file',
#    'unique': '3CU17C72261',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('945560-99999-2020.gz',
#   {'modify': '20200131153711',
#    'perm': 'adfr',
#    'size': '849',
#    'type': 'file',
#    'unique': '3CU25E15075',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('585690-99999-2020.gz',
#   {'modify': '20200131152730',
#    'perm': 'adfr',
#    'size': '12848',
#    'type': 'file',
#    'unique': '3CU17C72274',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('586330-99999-2020.gz',
#   {'modify': '20200131152731',
#    'perm': 'adfr',
#    'size': '9451',
#    'type': 'file',
#    'unique': '3CU17C72277',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('943650-99999-2020.gz',
#   {'modify': '20200131153708',
#    'perm': 'adfr',
#    'size': '26964',
#    'type': 'file',
#    'unique': '3CU25E1501B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('945410-99999-2020.gz',
#   {'modify': '20200131153711',
#    'perm': 'adfr',
#    'size': '5168',
#    'type': 'file',
#    'unique': '3CU25E1506A',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('945440-99999-2020.gz',
#   {'modify': '20200131153711',
#    'perm': 'adfr',
#    'size': '652',
#    'type': 'file',
#    'unique': '3CU25E1506C',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('260800-99999-2020.gz',
#   {'modify': '20200131152432',
#    'perm': 'adfr',
#    'size': '12974',
#    'type': 'file',
#    'unique': '3CU17BB14C1',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('942380-99999-2020.gz',
#   {'modify': '20200131153705',
#    'perm': 'adfr',
#    'size': '21098',
#    'type': 'file',
#    'unique': '3CU25DD4FC2',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('577070-99999-2020.gz',
#   {'modify': '20200131152726',
#    'perm': 'adfr',
#    'size': '11380',
#    'type': 'file',
#    'unique': '3CU17C72239',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('031340-99999-2020.gz',
#   {'modify': '20200131152126',
#    'perm': 'adfr',
#    'size': '24536',
#    'type': 'file',
#    'unique': '3CU173691E8',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('549290-99999-2020.gz',
#   {'modify': '20200131152719',
#    'perm': 'adfr',
#    'size': '11537',
#    'type': 'file',
#    'unique': '3CU17C721BB',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('564620-99999-2020.gz',
#   {'modify': '20200131152723',
#    'perm': 'adfr',
#    'size': '5443',
#    'type': 'file',
#    'unique': '3CU17C721EB',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('941410-99999-2020.gz',
#   {'modify': '20200131153703',
#    'perm': 'adfr',
#    'size': '7808',
#    'type': 'file',
#    'unique': '3CU25DD4F91',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('942010-99999-2020.gz',
#   {'modify': '20200131153704',
#    'perm': 'adfr',
#    'size': '1629',
#    'type': 'file',
#    'unique': '3CU25DD4FA6',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('258200-99999-2020.gz',
#   {'modify': '20200131152430',
#    'perm': 'adfr',
#    'size': '11287',
#    'type': 'file',
#    'unique': '3CU17BB14AB',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('547530-99999-2020.gz',
#   {'modify': '20200131152719',
#    'perm': 'adfr',
#    'size': '9207',
#    'type': 'file',
#    'unique': '3CU17C721AC',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('939850-99999-2020.gz',
#   {'modify': '20200131153701',
#    'perm': 'adfr',
#    'size': '8688',
#    'type': 'file',
#    'unique': '3CU25DD4F6A',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('548360-99999-2020.gz',
#   {'modify': '20200131152719',
#    'perm': 'adfr',
#    'size': '11843',
#    'type': 'file',
#    'unique': '3CU17C721B2',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('934200-99999-2020.gz',
#   {'modify': '20200131153659',
#    'perm': 'adfr',
#    'size': '8542',
#    'type': 'file',
#    'unique': '3CU25DD4F43',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('935270-99999-2020.gz',
#   {'modify': '20200131153700',
#    'perm': 'adfr',
#    'size': '8159',
#    'type': 'file',
#    'unique': '3CU25DD4F4B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('547250-99999-2020.gz',
#   {'modify': '20200131152719',
#    'perm': 'adfr',
#    'size': '10648',
#    'type': 'file',
#    'unique': '3CU17C721A9',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('076810-99999-2020.gz',
#   {'modify': '20200131152218',
#    'perm': 'adfr',
#    'size': '12636',
#    'type': 'file',
#    'unique': '3CU17B30CBC',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('930690-99999-2020.gz',
#   {'modify': '20200131153659',
#    'perm': 'adfr',
#    'size': '7744',
#    'type': 'file',
#    'unique': '3CU25DD4F28',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('544230-99999-2020.gz',
#   {'modify': '20200131152718',
#    'perm': 'adfr',
#    'size': '8632',
#    'type': 'file',
#    'unique': '3CU17C72199',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('913760-00492-2020.gz',
#   {'modify': '20200131153652',
#    'perm': 'adfr',
#    'size': '15526',
#    'type': 'file',
#    'unique': '3CU25DD4E8D',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('915515-99999-2020.gz',
#   {'modify': '20200131153653',
#    'perm': 'adfr',
#    'size': '12534',
#    'type': 'file',
#    'unique': '3CU25DD4EA4',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('915730-99999-2020.gz',
#   {'modify': '20200131153653',
#    'perm': 'adfr',
#    'size': '5220',
#    'type': 'file',
#    'unique': '3CU25DD4EAF',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('245070-99999-2020.gz',
#   {'modify': '20200131152423',
#    'perm': 'adfr',
#    'size': '11168',
#    'type': 'file',
#    'unique': '3CU17BB1443',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('246910-99999-2020.gz',
#   {'modify': '20200131152424',
#    'perm': 'adfr',
#    'size': '8727',
#    'type': 'file',
#    'unique': '3CU17BB145A',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('540960-99999-2020.gz',
#   {'modify': '20200131152715',
#    'perm': 'adfr',
#    'size': '10929',
#    'type': 'file',
#    'unique': '3CU17C72178',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('247580-99999-2020.gz',
#   {'modify': '20200131152424',
#    'perm': 'adfr',
#    'size': '10545',
#    'type': 'file',
#    'unique': '3CU17BB1462',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('912180-41414-2020.gz',
#   {'modify': '20200131153651',
#    'perm': 'adfr',
#    'size': '54582',
#    'type': 'file',
#    'unique': '3CU25DD4E5F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('531920-99999-2020.gz',
#   {'modify': '20200131152713',
#    'perm': 'adfr',
#    'size': '8856',
#    'type': 'file',
#    'unique': '3CU17C7214C',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('532310-99999-2020.gz',
#   {'modify': '20200131152713',
#    'perm': 'adfr',
#    'size': '11514',
#    'type': 'file',
#    'unique': '3CU17C7214D',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('878520-99999-2020.gz',
#   {'modify': '20200131153641',
#    'perm': 'adfr',
#    'size': '9038',
#    'type': 'file',
#    'unique': '3CU25DD4DAF',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('890620-99999-2020.gz',
#   {'modify': '20200131153644',
#    'perm': 'adfr',
#    'size': '23856',
#    'type': 'file',
#    'unique': '3CU25DD4DE5',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('895140-99999-2020.gz',
#   {'modify': '20200131153645',
#    'perm': 'adfr',
#    'size': '3088',
#    'type': 'file',
#    'unique': '3CU25DD4E0B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('895750-99999-2020.gz',
#   {'modify': '20200131153645',
#    'perm': 'adfr',
#    'size': '3607',
#    'type': 'file',
#    'unique': '3CU25DD4E18',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('896590-99999-2020.gz',
#   {'modify': '20200131153646',
#    'perm': 'adfr',
#    'size': '10749',
#    'type': 'file',
#    'unique': '3CU25DD4E27',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('075700-99999-2020.gz',
#   {'modify': '20200131152214',
#    'perm': 'adfr',
#    'size': '27568',
#    'type': 'file',
#    'unique': '3CU17B30C83',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('489440-99999-2020.gz',
#   {'modify': '20200131152708',
#    'perm': 'adfr',
#    'size': '221',
#    'type': 'file',
#    'unique': '3CU17C720D5',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('875340-99999-2020.gz',
#   {'modify': '20200131153639',
#    'perm': 'adfr',
#    'size': '28324',
#    'type': 'file',
#    'unique': '3CU25DD4D7F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('877840-99999-2020.gz',
#   {'modify': '20200131153640',
#    'perm': 'adfr',
#    'size': '8143',
#    'type': 'file',
#    'unique': '3CU25DD4DA7',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('877910-99999-2020.gz',
#   {'modify': '20200131153640',
#    'perm': 'adfr',
#    'size': '19488',
#    'type': 'file',
#    'unique': '3CU25DD4DAA',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('488080-99999-2020.gz',
#   {'modify': '20200131152704',
#    'perm': 'adfr',
#    'size': '10777',
#    'type': 'file',
#    'unique': '3CU17C720A0',
#    'unix.group': '4021',
#    'unix.mode': '0664',
# ...
#    'unix.owner': '4021'}),
#  ('287220-99999-2020.gz',
#   {'modify': '20200131152446',
#    'perm': 'adfr',
#    'size': '47468',
#    'type': 'file',
#    'unique': '3CU17BB167E',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('997173-99999-2020.gz',
#   {'modify': '20200131153806',
#    'perm': 'adfr',
#    'size': '19280',
#    'type': 'file',
#    'unique': '3CU25E55521',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('013450-99999-2020.gz',
#   {'modify': '20200131152045',
#    'perm': 'adfr',
#    'size': '14336',
#    'type': 'file',
#    'unique': '3CU17328F2A',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('085370-99999-2020.gz',
#   {'modify': '20200131152231',
#    'perm': 'adfr',
#    'size': '7818',
#    'type': 'file',
#    'unique': '3CU17B30D90',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('618180-99999-2020.gz',
#   {'modify': '20200131152752',
#    'perm': 'adfr',
#    'size': '733',
#    'type': 'file',
#    'unique': '3CU17C723CB',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('994560-99999-2020.gz',
#   {'modify': '20200131153804',
#    'perm': 'adfr',
#    'size': '36245',
#    'type': 'file',
#    'unique': '3CU25E554FE',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('994973-99999-2020.gz',
#   {'modify': '20200131153806',
#    'perm': 'adfr',
#    'size': '6598',
#    'type': 'file',
#    'unique': '3CU25E55517',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('616970-99999-2020.gz',
#   {'modify': '20200131152751',
#    'perm': 'adfr',
#    'size': '17598',
#    'type': 'file',
#    'unique': '3CU17C723B9',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('279350-99999-2020.gz',
#   {'modify': '20200131152443',
#    'perm': 'adfr',
#    'size': '10407',
#    'type': 'file',
#    'unique': '3CU17BB15AE',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('994200-99999-2020.gz',
#   {'modify': '20200131153802',
#    'perm': 'adfr',
#    'size': '42724',
#    'type': 'file',
#    'unique': '3CU25E554E6',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('277760-99999-2020.gz',
#   {'modify': '20200131152442',
#    'perm': 'adfr',
#    'size': '11926',
#    'type': 'file',
#    'unique': '3CU17BB159A',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('013600-99999-2020.gz',
#   {'modify': '20200131152045',
#    'perm': 'adfr',
#    'size': '5544',
#    'type': 'file',
#    'unique': '3CU17328F39',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('971925-99999-2020.gz',
#   {'modify': '20200131153751',
#    'perm': 'adfr',
#    'size': '26462',
#    'type': 'file',
#    'unique': '3CU25E5540A',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('974300-99999-2020.gz',
#   {'modify': '20200131153753',
#    'perm': 'adfr',
#    'size': '11838',
#    'type': 'file',
#    'unique': '3CU25E5541D',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('982320-99999-2020.gz',
#   {'modify': '20200131153755',
#    'perm': 'adfr',
#    'size': '10941',
#    'type': 'file',
#    'unique': '3CU25E55449',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('272770-99999-2020.gz',
#   {'modify': '20200131152439',
#    'perm': 'adfr',
#    'size': '12482',
#    'type': 'file',
#    'unique': '3CU17BB1560',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('606020-99999-2020.gz',
#   {'modify': '20200131152745',
#    'perm': 'adfr',
#    'size': '5943',
#    'type': 'file',
#    'unique': '3CU17C72349',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('969355-99999-2020.gz',
#   {'modify': '20200131153750',
#    'perm': 'adfr',
#    'size': '278',
#    'type': 'file',
#    'unique': '3CU25E153EE',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('013680-99999-2020.gz',
#   {'modify': '20200131152045',
#    'perm': 'adfr',
#    'size': '22528',
#    'type': 'file',
#    'unique': '3CU17328F41',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('084510-99999-2020.gz',
#   {'modify': '20200131152228',
#    'perm': 'adfr',
#    'size': '65873',
#    'type': 'file',
#    'unique': '3CU17B30D65',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('270830-99999-2020.gz',
#   {'modify': '20200131152439',
#    'perm': 'adfr',
#    'size': '12286',
#    'type': 'file',
#    'unique': '3CU17BB154B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('959670-99999-2020.gz',
#   {'modify': '20200131153743',
#    'perm': 'adfr',
#    'size': '15224',
#    'type': 'file',
#    'unique': '3CU25E15375',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('959860-99999-2020.gz',
#   {'modify': '20200131153744',
#    'perm': 'adfr',
#    'size': '15164',
#    'type': 'file',
#    'unique': '3CU25E15380',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('967490-99999-2020.gz',
#   {'modify': '20200131153749',
#    'perm': 'adfr',
#    'size': '50166',
#    'type': 'file',
#    'unique': '3CU25E153DD',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('605800-99999-2020.gz',
#   {'modify': '20200131152744',
#    'perm': 'adfr',
#    'size': '22475',
#    'type': 'file',
#    'unique': '3CU17C72345',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('957160-99999-2020.gz',
#   {'modify': '20200131153737',
#    'perm': 'adfr',
#    'size': '9292',
#    'type': 'file',
#    'unique': '3CU25E152F1',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('083830-99999-2020.gz',
#   {'modify': '20200131152226',
#    'perm': 'adfr',
#    'size': '24860',
#    'type': 'file',
#    'unique': '3CU17B30D56',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('956600-99999-2020.gz',
#   {'modify': '20200131153736',
#    'perm': 'adfr',
#    'size': '1660',
#    'type': 'file',
#    'unique': '3CU25E152C4',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('605500-99999-2020.gz',
#   {'modify': '20200131152744',
#    'perm': 'adfr',
#    'size': '27591',
#    'type': 'file',
#    'unique': '3CU17C7233E',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('270370-99999-2020.gz',
#   {'modify': '20200131152439',
#    'perm': 'adfr',
#    'size': '12074',
#    'type': 'file',
#    'unique': '3CU17BB1548',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('956450-99999-2020.gz',
#   {'modify': '20200131153735',
#    'perm': 'adfr',
#    'size': '1563',
#    'type': 'file',
#    'unique': '3CU25E152BA',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('603200-99999-2020.gz',
#   {'modify': '20200131152740',
#    'perm': 'adfr',
#    'size': '9928',
#    'type': 'file',
#    'unique': '3CU17C722F8',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('604190-99999-2020.gz',
#   {'modify': '20200131152742',
#    'perm': 'adfr',
#    'size': '36125',
#    'type': 'file',
#    'unique': '3CU17C72315',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('033233-99999-2020.gz',
#   {'modify': '20200131152129',
#    'perm': 'adfr',
#    'size': '37868',
#    'type': 'file',
#    'unique': '3CU17369235',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('956400-99999-2020.gz',
#   {'modify': '20200131153735',
#    'perm': 'adfr',
#    'size': '5100',
#    'type': 'file',
#    'unique': '3CU25E152B6',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('588340-99999-2020.gz',
#   {'modify': '20200131152731',
#    'perm': 'adfr',
#    'size': '12271',
#    'type': 'file',
#    'unique': '3CU17C72282',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('590960-99999-2020.gz',
#   {'modify': '20200131152732',
#    'perm': 'adfr',
#    'size': '9007',
#    'type': 'file',
#    'unique': '3CU17C72295',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('956380-99999-2020.gz',
#   {'modify': '20200131153735',
#    'perm': 'adfr',
#    'size': '12421',
#    'type': 'file',
#    'unique': '3CU25E152B3',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('600350-99999-2020.gz',
#   {'modify': '20200131152737',
#    'perm': 'adfr',
#    'size': '42604',
#    'type': 'file',
#    'unique': '3CU17C722D0',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('082270-99999-2020.gz',
#   {'modify': '20200131152225',
#    'perm': 'adfr',
#    'size': '19807',
#    'type': 'file',
#    'unique': '3CU17B30D35',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('587520-99999-2020.gz',
#   {'modify': '20200131152731',
#    'perm': 'adfr',
#    'size': '12943',
#    'type': 'file',
#    'unique': '3CU17C7227F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('263890-99999-2020.gz',
#   {'modify': '20200131152434',
#    'perm': 'adfr',
#    'size': '10758',
#    'type': 'file',
#    'unique': '3CU17BB14F6',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('264350-99999-2020.gz',
#   {'modify': '20200131152435',
#    'perm': 'adfr',
#    'size': '8943',
#    'type': 'file',
#    'unique': '3CU17BB1501',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('956350-99999-2020.gz',
#   {'modify': '20200131153735',
#    'perm': 'adfr',
#    'size': '11010',
#    'type': 'file',
#    'unique': '3CU25E152B0',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('575160-99999-2020.gz',
#   {'modify': '20200131152726',
#    'perm': 'adfr',
#    'size': '32994',
#    'type': 'file',
#    'unique': '3CU17C72230',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('576550-99999-2020.gz',
#   {'modify': '20200131152726',
#    'perm': 'adfr',
#    'size': '8342',
#    'type': 'file',
#    'unique': '3CU17C72236',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('582210-99999-2020.gz',
#   {'modify': '20200131152728',
#    'perm': 'adfr',
#    'size': '11949',
#    'type': 'file',
#    'unique': '3CU17C7225C',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('955330-99999-2020.gz',
#   {'modify': '20200131153733',
#    'perm': 'adfr',
#    'size': '1293',
#    'type': 'file',
#    'unique': '3CU25E15277',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('585270-99999-2020.gz',
#   {'modify': '20200131152730',
#    'perm': 'adfr',
#    'size': '11225',
#    'type': 'file',
#    'unique': '3CU17C72271',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('585560-99999-2020.gz',
#   {'modify': '20200131152730',
#    'perm': 'adfr',
#    'size': '9307',
#    'type': 'file',
#    'unique': '3CU17C72273',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('949570-99999-2020.gz',
#   {'modify': '20200131153730',
#    'perm': 'adfr',
#    'size': '15182',
#    'type': 'file',
#    'unique': '3CU25E15214',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('949790-99999-2020.gz',
#   {'modify': '20200131153730',
#    'perm': 'adfr',
#    'size': '1043',
#    'type': 'file',
#    'unique': '3CU25E1522F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('952840-99999-2020.gz',
#   {'modify': '20200131153731',
#    'perm': 'adfr',
#    'size': '1005',
#    'type': 'file',
#    'unique': '3CU25E15248',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('953050-99999-2020.gz',
#   {'modify': '20200131153732',
#    'perm': 'adfr',
#    'size': '14933',
#    'type': 'file',
#    'unique': '3CU25E15259',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('572450-99999-2020.gz',
#   {'modify': '20200131152724',
#    'perm': 'adfr',
#    'size': '8859',
#    'type': 'file',
#    'unique': '3CU17C7221A',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('949540-99999-2020.gz',
#   {'modify': '20200131153729',
#    'perm': 'adfr',
#    'size': '20345',
#    'type': 'file',
#    'unique': '3CU25E1520D',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('080270-99999-2020.gz',
#   {'modify': '20200131152221',
#    'perm': 'adfr',
#    'size': '10567',
#    'type': 'file',
#    'unique': '3CU17B30CF2',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('949510-99999-2020.gz',
#   {'modify': '20200131153729',
#    'perm': 'adfr',
#    'size': '20920',
#    'type': 'file',
#    'unique': '3CU25E1520B',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('260940-99999-2020.gz',
#   {'modify': '20200131152432',
#    'perm': 'adfr',
#    'size': '13044',
#    'type': 'file',
#    'unique': '3CU17BB14C2',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('260990-99999-2020.gz',
#   {'modify': '20200131152432',
#    'perm': 'adfr',
#    'size': '10349',
#    'type': 'file',
#    'unique': '3CU17BB14C3',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('567480-99999-2020.gz',
#   {'modify': '20200131152723',
#    'perm': 'adfr',
#    'size': '7973',
#    'type': 'file',
#    'unique': '3CU17C721F7',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('260780-99999-2020.gz',
#   {'modify': '20200131152432',
#    'perm': 'adfr',
#    'size': '10051',
#    'type': 'file',
#    'unique': '3CU17BB14C0',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('077800-99999-2020.gz',
#   {'modify': '20200131152219',
#    'perm': 'adfr',
#    'size': '75509',
#    'type': 'file',
#    'unique': '3CU17B30CD2',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('948570-99999-2020.gz',
#   {'modify': '20200131153725',
#    'perm': 'adfr',
#    'size': '15022',
#    'type': 'file',
#    'unique': '3CU25E151AA',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('255940-99999-2020.gz',
#   {'modify': '20200131152430',
#    'perm': 'adfr',
#    'size': '8373',
#    'type': 'file',
#    'unique': '3CU17BB149E',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('561160-99999-2020.gz',
#   {'modify': '20200131152721',
#    'perm': 'adfr',
#    'size': '8574',
#    'type': 'file',
#    'unique': '3CU17C721D4',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('948550-99999-2020.gz',
#   {'modify': '20200131153725',
#    'perm': 'adfr',
#    'size': '16093',
#    'type': 'file',
#    'unique': '3CU25E151A9',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('248560-99999-2020.gz',
#   {'modify': '20200131152425',
#    'perm': 'adfr',
#    'size': '10488',
#    'type': 'file',
#    'unique': '3CU17BB146F',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('249080-99999-2020.gz',
#   {'modify': '20200131152425',
#    'perm': 'adfr',
#    'size': '11538',
#    'type': 'file',
#    'unique': '3CU17BB1473',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('948270-99999-2020.gz',
#   {'modify': '20200131153724',
#    'perm': 'adfr',
#    'size': '8507',
#    'type': 'file',
#    'unique': '3CU25E15181',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('560790-99999-2020.gz',
#   {'modify': '20200131152721',
#    'perm': 'adfr',
#    'size': '11397',
#    'type': 'file',
#    'unique': '3CU17C721CF',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('248020-99999-2020.gz',
#   {'modify': '20200131152425',
#    'perm': 'adfr',
#    'size': '11504',
#    'type': 'file',
#    'unique': '3CU17BB1468',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ('947800-99999-2020.gz',
#   {'modify': '20200131153723',
#    'perm': 'adfr',
#    'size': '1401',
#    'type': 'file',
#    'unique': '3CU25E150FF',
#    'unix.group': '4021',
#    'unix.mode': '0664',
#    'unix.owner': '4021'}),
#  ...]

# %%
fname = files[2][0]
file = get_file(ftp, fname)

# %%
file = gzip.decompress(file)

# %%
import datetime
import pprint

def value_or_missing(val):
    '''
    ISD values uses a string of 9s to indicate missing data.
    This method checks if the data is missing and returns None if it is,
    or the actual string if not
    '''
    nval = len(val)
    return None if (val == "9"*nval) else val

def parse_isd_line(line):
    '''
    Parses a NOAA isd line. Returns data as a dictionary.
    '''
    # Station data
    var_data_len = int(line[0:4])
    usaf_station_id = value_or_missing(line[4:10])
    wban_station_id = value_or_missing(line[10:15])
    date = value_or_missing(line[15:27])
    date = datetime.datetime.strptime(date, "%Y%m%d%H%M") if date is not None else None
    latitude = value_or_missing(line[28:34])
    latitude = float(latitude) / 1000.0 if latitude else None
    longitude = value_or_missing(line[34:41])
    longitude = float(longitude) / 1000.0 if longitude else None
    report_type = value_or_missing(line[41:46])
    elevation = value_or_missing(line[46:51])
    elevation = int(elevation) if elevation else None
    call_letters = value_or_missing(line[51:56])
    qc_process = value_or_missing(line[56:59])
    
    # Air temp
    air_temp_c = value_or_missing(line[87:92])
    air_temp_c = float(air_temp_c) / 10. if air_temp_c else None
    
    return {
        "var_data_len": var_data_len,
        "usaf_station_id": usaf_station_id,
        "wban_station_id": wban_station_id,
        "date": date,
        "latitude": latitude,
        "longitude": longitude,
        "report_type": report_type,
        "elevation_meters": elevation,
        "call_letters": call_letters,
        "qc_process": qc_process,
        "air_temp_c": air_temp_c,
    }

for line in file.decode().split("\n")[:20]:
    data = parse_isd_line(line)
    pprint.pprint(data)
    print(line, "\n")
# Out:
# {'air_temp_c': 2.1,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 1, 0, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 153,
#  'wban_station_id': None}
# 0153359270999992020010100004+45250+055083FM-12+007499999V0201801N002019999999N999999999+00211-00011999999ADDGA1081+008001061GE19MSL   +99999+99999GF108991081999008001999999MA1999999101491MD1710111+9999REMSYN04835927 425// 81802 10021 21001 30149 57011 885//=
#
# {'air_temp_c': 1.9,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 1, 3, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 169,
#  'wban_station_id': None}
# 0169359270999992020010103004+45250+055083FM-12+007499999V0201601N002019999999N999999999+00191-00061999999ADDGA1081+008001061GE19MSL   +99999+99999GF108991081999008001999999MA1999999101361MD1710131+9999REMSYN06435927 325// 81602 10019 21006 30136 57013 885// 555 20004 7000/=
#
# {'air_temp_c': 3.8,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 1, 6, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 176,
#  'wban_station_id': None}
# 0176359270999992020010106004+45250+055083FM-12+007499999V0201801N002019999999N020000199+00381+00041999999ADDGA1071+008001061GE19MSL   +99999+99999GF107991071999008001999999KA1240N+00041MA1999999101431MD1310071+9999REMSYN05835927 32598 71802 10038 20004 30143 53007 87500 333 20004=
#
# {'air_temp_c': 6.7,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 1, 9, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 153,
#  'wban_station_id': None}
# 0153359270999992020010109004+45250+055083FM-12+007499999V0201601N002019999999N020000199+00671+00361999999ADDGA1061+008001071GE19MSL   +99999+99999GF106991061999008001999999MA1999999101331MD1810101+9999REMSYN04835927 42598 61602 10067 20036 30133 58010 86600=
#
# {'air_temp_c': 7.6,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 1, 12, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 136,
#  'wban_station_id': None}
# 0136359270999992020010112004+45250+055083FM-12+007499999V0201801N003012200019N020000199+00761+00291999999ADDGA1999+008001999GE19MSL   +99999+99999GF102991999999008001999999REMSYN06035927 42598 21803 10076 20029 21801 30132 42598 57002 82500=
#
# {'air_temp_c': 3.4,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 1, 15, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 176,
#  'wban_station_id': None}
# 0176359270999992020010115004+45250+055083FM-12+007499999V0201801N001012200019N999999999+00341+00081999999ADDGA1031+012501061GE19MSL   +99999+99999GF103991031999012501999999KA1240M+00941MA1999999101321MD1410001+9999REMSYN05835927 326// 31801 10034 20008 30132 54000 83400 333 10094=
#
# {'air_temp_c': 4.7,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 1, 18, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 176,
#  'wban_station_id': None}
# 0176359270999992020010118004+45250+055083FM-12+007499999V0202301N002012200019N999999999+00471+00351999999ADDGA1021+008001061GE19MSL   +99999+99999GF102991021999008001999999KA1120M+00941MA1999999101501MD1310181+9999REMSYN05835927 325// 22302 10047 20035 30150 53018 82500 333 10094=
#
# {'air_temp_c': 2.0,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 1, 21, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 87,
#  'wban_station_id': None}
# 0087359270999992020010121004+45250+055083FM-12+007499999V0202701N002019999999N999999999+00201-00051999999ADDMD1210061+9999REMSYN04235927 429// 02702 10020 21005 30056 52006=EQDQ011005.63APOSP
#
# {'air_temp_c': -1.4,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 2, 0, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 83,
#  'wban_station_id': None}
# 0083359270999992020010200004+45250+055083FM-12+007499999V0201401N002019999999N999999999-00141-00401999999ADDMA1999999101691MD1210131+9999REMSYN04235927 429// 01402 11014 21040 30169 52013=
#
# {'air_temp_c': -2.6,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 2, 3, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 169,
#  'wban_station_id': None}
# 0169359270999992020010203004+45250+055083FM-12+007499999V0209999C999992200019N999999999-00261-00501999999ADDGA1021+999999031GE19MSL   +99999+99999GF102991021999999999999999MA1999999101821MD1210131+9999REMSYN06435927 329// 20000 11026 21050 30182 52013 82080 555 21035 7000/=
#
# {'air_temp_c': -0.2,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 2, 6, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 220,
#  'wban_station_id': None}
# 0220359270999992020010206004+45250+055083FM-12+007499999V0201801N001019999999N004000199-00021-00231999999ADDAY121021AY211021GA1031+999999031GA2999+999999001GE19MSL   +99999+99999GF106991031999999999999999KA1240N-00351MA1999999101991MD1210171+9999MW1101REMSYN06435927 31996 61801 11002 21023 30199 52017 71021 83042 333 21035=
#
# {'air_temp_c': 4.6,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 2, 9, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 169,
#  'wban_station_id': None}
# 0169359270999992020010209004+45250+055083FM-12+007499999V0202701N001019999999N020000199+00461+00041999999ADDGA1031+999999031GA2999+999999001GE19MSL   +99999+99999GF106991031999999999999999MA1999999101991MD1410001+9999REMSYN04835927 42998 62701 10046 20004 30199 54000 83042=
#
# {'air_temp_c': 4.9,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 2, 12, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 169,
#  'wban_station_id': None}
# 0169359270999992020010212004+45250+055083FM-12+007499999V0202701N001019999999N020000199+00491-00011999999ADDGA1051+012501061GA2999+999999001GE19MSL   +99999+99999GF106991051999012501999999MA1999999102061MD1310071+9999REMSYN04835927 42698 62701 10049 21001 30206 53007 85502=
#
# {'air_temp_c': 3.0,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 2, 15, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 176,
#  'wban_station_id': None}
# 0176359270999992020010215004+45250+055083FM-12+007499999V0202701N001019999999N999999999+00301-00121999999ADDGA1081+012501061GE19MSL   +99999+99999GF108991081999012501999999KA1240M+00671MA1999999102141MD1210081+9999REMSYN05835927 326// 82701 10030 21012 30214 52008 885// 333 10067=
#
# {'air_temp_c': 1.4,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 2, 18, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 176,
#  'wban_station_id': None}
# 0176359270999992020010218004+45250+055083FM-12+007499999V0202701N001019999999N999999999+00141-00151999999ADDGA1081+012501061GE19MSL   +99999+99999GF108991081999012501999999KA1120M+00671MA1999999102231MD1210091+9999REMSYN05835927 326// 82701 10014 21015 30223 52009 885// 333 10067=
#
# {'air_temp_c': 0.1,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 2, 21, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 181,
#  'wban_station_id': None}
# 0181359270999992020010221004+45250+055083FM-12+007499999V0202701N001019999999N999999999+00011-00101999999ADDAY171021AY221021GA1081+004501051GE19MSL   +99999+99999GF108991081999004501999999MA1999999102281MD1210051+9999MW1701REMSYN05435927 414// 82701 10001 21010 30228 52005 77072 8802/=
#
# {'air_temp_c': 0.2,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 3, 0, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 181,
#  'wban_station_id': None}
# 0181359270999992020010300004+45250+055083FM-12+007499999V0203201N002019999999N999999999+00021-00071999999ADDAY171021AY221021GA1081+004501051GE19MSL   +99999+99999GF108991081999004501999999MA1999999102311MD1210031+9999MW1211REMSYN05435927 414// 83202 10002 21007 30231 52003 72172 8802/=
#
# {'air_temp_c': -0.4,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 3, 6, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 221,
#  'wban_station_id': None}
# 0221359270999992020010306004+45250+055083FM-12+007499999V0202701N002019999999N020000199-00041-00251999999ADDAA100000631AY171021AY221021GA1081+008001051GE19MSL   +99999+99999GF108991081999008001999999KA1240N+00001MA1999999102501MD1210181+9999MW1021REMSYN07035927 11598 82702 11004 21025 30250 52018 69960 70272 8802/ 333 20000=
#
# {'air_temp_c': -0.3,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 3, 9, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 153,
#  'wban_station_id': None}
# 0153359270999992020010309004+45250+055083FM-12+007499999V0203201N002019999999N020000199-00031-00441999999ADDGA1061+008001061GE19MSL   +99999+99999GF106991061999008001999999MA1999999102521MD1210021+9999REMSYN04835927 42598 63202 11003 21044 30252 52002 86500=
#
# {'air_temp_c': 0.4,
#  'call_letters': None,
#  'date': datetime.datetime(2020, 1, 3, 12, 0),
#  'elevation_meters': 74,
#  'latitude': 45.25,
#  'longitude': 55.083,
#  'qc_process': 'V02',
#  'report_type': 'FM-12',
#  'usaf_station_id': '359270',
#  'var_data_len': 153,
#  'wban_station_id': None}
# 0153359270999992020010312004+45250+055083FM-12+007499999V0203201N002019999999N020000199+00041-00471999999ADDGA1061+008001061GE19MSL   +99999+99999GF106991061999008001999999MA1999999102531MD1210011+9999REMSYN04835927 42598 63202 10004 21047 30253 52001 86400=
